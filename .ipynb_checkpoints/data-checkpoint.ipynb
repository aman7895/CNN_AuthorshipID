# %%
#generate graphs with chunk_size, batch size
import psycopg2
import pandas as pd
import nltk
import re #This is to parse the HTML code from the given text
from sshtunnel import SSHTunnelForwarder #This is to connect to the local Database

def getCharAuthorData(authors, doc, documentTable = 'document_unicode', chunk_size = 1000):
    df = pd.DataFrame()
    conn = None
    output = []
    i = 1
    #nltk.download('punkt')
    try:
        
        with SSHTunnelForwarder(("srn01.cs.cityu.edu.hk", 22),
                            ssh_username='stylometry',
                            ssh_password='stylometry',
                            remote_bind_address=('localhost', 5432),
                            local_bind_address=('localhost', 5400)):
            
            conn = psycopg2.connect(user="stylometry", password="stylometry",
                                database="stylometry", host="localhost", port=5400)
            
            
            cur = conn.cursor()
            query = "SELECT author_id, doc_content FROM " + str(documentTable) + " WHERE author_id IN ("
            flag = False
            for auth in authors:
                if not flag:
                    query = query + str(auth)
                    flag = True
                else:
                    query = query + ", " + str(auth)
            query = query + ") AND doc_id <> '" + str(doc) + "' ;"
            cur.execute(query)
            print("Execution completed")
            rows = cur.fetchall()
            
            print("Read completed")
            print("Number of rows: %s" % (len(rows)))
            for row in rows:
                #tokens = nltk.word_tokenize(row[1])
                ###row[1] = row[1].replace("\r\n","")
                
                temp = re.sub('<[^<]+?>', '', row[1])
                temp = temp.replace("\r\n","") 
                temp = temp.replace("\n","") 
                chars = list(temp)
                
                chunk1 = []
                for x in chars:
                    if (i < chunk_size):
                        chunk1.append(x)
                        i += 1
                    else:
                        chunk1.append(x)
                        xx = ''.join(chunk1)
                        xx = str(xx)
                        chunk1 = []
                        output.append([row[0], xx])
                        i = 1
                if len(chunk1) > 0:
                    xx = ''.join(chunk1)
                    xx = str(xx)
                    chunk1 = []
                    output.append([row[0], xx])
                    i = 1

            df = pd.DataFrame(output, columns=["author_id", "doc_content"])
            print(df.dtypes)
            print("Data Frame created: Shape: %s" % (str(df.shape)))

    except psycopg2.Error as e:
        if conn:
            conn.rollback()
        print('Error %s' % e)
        sys.exit(1)

    finally:
        if conn is not None:
            conn.close()
    
    print df
    return df

# %%
authors=[ 1240, 172 ]
doc = 61
df = getCharAuthorData(authors, doc, documentTable = 'document_unicode', chunk_size = 1000)
# Out:
# Execution completed
# Read completed
# Number of rows: 2
# author_id       int64
# doc_content    object
# dtype: object
# Data Frame created: Shape: (171, 2)
#      author_id                                        doc_content
# 0          172  \n\n\n\nThis eBook was prepared by Gunther Ole...
# 1          172  \n\n        Beim Hauptmann\n\n[Hauptmann auf d...
# 2          172  ptmann.\n\nHAUPTMANN: Woyzeck, Er sieht immer ...
# 3          172   Herr\nsprach: Lasset die Kleinen zu mir komme...
# 4          172  CK: Ja, Herr Hauptmann, die Tugend - ich hab's...
# 5          172  änen. - [Leise:]\nAndres, das waren die Freima...
# 6          172  arie mit ihrem Kind am Fenster. Margret. Der Z...
# 7          172  ast ein klein Kind und kein' Mann!\n        Ei...
# 8          172  meint, man wär' blind. Sonst\nscheint als die ...
# 9          172  zu sehen das astronomische Pferd\nund die klei...
# 10         172   Pferd vorführend]: Zeig dein Talent! Zeig dei...
# 11         172   Willst du mehr\nsein als Staub, Sand, Dreck? ...
# 12         172        führt dich an deiner Hand\n        fort ...
# 13         172   Tropfen stehn ihm auf der\nStirn; alles Arbei...
# 14         172   Natur! Woyzeck, der Mensch ist frei, in dem\n...
# 15         172  mit der größten\nKaltblütigkeit. Behüte, wer w...
# 16         172  lis,\ndie zweite Spezies, sehr schön ausgepräg...
# 17         172  erment, wir wollen\neine Zucht Tambourmajors a...
# 18         172  a cerebri\nkriegen; Sie können sie aber vielle...
# 19         172  ber ich kann auch, wenn ich will, Herr Doktor,...
# 20         172  n?\n\nHAUPTMANN: Was der Kerl ein Gesicht mach...
# 21         172  ön Wetter, hh. Sehn Sie, so ein schöner, feste...
# 22         172  l hinausräuchern könnt'! Du hast ein' roten Mu...
# 23         172  Woyzeck. Andres.]\n\nANDRES [singt]:\n        ...
# 24         172  Ich hab' ein Hemdlein an, das ist nicht mein;\...
# 25         172  en]: Immer zu, imer zu -\n\nWOYZECK [erstickt]...
# 26         172  leben sollen, wenn er dem Menschen nicht die E...
# 27         172  res murmelt im Schlaf.]\n\nWOYZECK [schüttelt ...
# 28         172  estiert, und ihre Verhältnisse zum Raum, zur E...
# 29         172  Daktor, es wird mir dunkel! - [Er setzt sich.]...
# ..         ...                                                ...
# 141        172  lein).\nDie Ungeheuer! - »Es ist noch nicht la...
# 142        172  \nSiebente Szene\n\nDie Conciergerie\n\nLacroi...
# 143        172  ulnis - vielleicht, daß einem der Tod das Lebe...
# 144        172  reit\ngemacht, da ist nichts leer, alles voll ...
# 145        172  am ließe! - Und wenn\nich ganz zerfiele, mich ...
# 146        172  noch stark genug, um den\nDezemvirn die Leiche...
# 147        172  Augen setzen sollte, von den Debatten auszusch...
# 148        172  illotine lecken! (Heftige Bewegung unter\nden ...
# 149        172  r sagt das?\n\nErster Bürger.\nDanton.\n\nZwei...
# 150        172  ann schnell\nzurück, ich will seine Blicke aus...
# 151        172  eh, du begreifst mich nicht! (Sie gehen ab.)\n...
# 152        172  ine Lucile!\n\nDanton.\nSei ruhig, mein Junge!...
# 153        172  . -\n\nDanton.\nWill denn die Uhr nicht ruhen?...
# 154        172  .\n\nAch, das hilft nichts! Jawohl, es ist so ...
# 155        172  e.\nOh, oh!\n\nDanton (schüttelt ihn).\nWillst...
# 156        172  st du?\n\nCamille.\nDie Nachtgedanken.\n\nDant...
# 157        172  e das?\n\nZweiter Fuhrmann.\nWer ist der beste...
# 158        172  die Fenster\nder Gefangnen).\nCamille, Camille...
# 159        172  ill ihm nachlaufen; komm, süßer\nFreund, hilf ...
# 160        172  sten Dinge unter der Sonne. Sie wird sich jetz...
# 161        172   Camille nie freundlicher war als zwei Tage vo...
# 162        172  schiede sind so groß nicht, wir alle sind Schu...
# 163        172  ker machten die heroische\nFratze.\n\nDanton.\...
# 164        172  nd wie\nein wollüstiger Hauch in himmlischen O...
# 165        172  Freue dich, Camille, wir bekommen eine schöne ...
# 166        172  Ich küsse sie nicht, daß kein Hauch, kein Seuf...
# 167        172  räsentierteller! - Meine\nHerren, ich will mic...
# 168        172  e Arzt.\n\nHérault (will Danton umarmen).\nAch...
# 169        172  sich die Augen und\nstößt einen Schrei aus. Na...
# 170        172  rvaters Fenster -\n        Kerl, wo bleibst so...
#
# [171 rows x 2 columns]

# %%
1458
